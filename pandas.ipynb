# %%
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 3.0.3

# %%
s = pd.Series([10,20,30,40], index=['a','b','c','d'])
print(s)
s['c']
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# np.int64(30)

# %%
s[s>25]
# Out:
# c    30
# d    40
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
s.describe()
# Out:
# count     4.000000
# mean     25.000000
# std      12.909944
# min      10.000000
# 25%      17.500000
# 50%      25.000000
# 75%      32.500000
# max      40.000000
# dtype: float64

# %%
s.mean()
# Out:
# np.float64(25.0)

# %%
data = {
    'Name' : ['An','Binh','Cuong','Dung'],
    'Age' : [20,21,22,23],
    'City' : ['HaNoi','HCM','DaNang','HaNoi'],
    'GPA' : [3.5,3.8,3.2,3.6]
}
df = pd.DataFrame(data)
print(df)
print(df.shape)
print(df.columns)
print(df.values)
print(df.describe)
# Out:
#     Name  Age    City  GPA
# 0     An   20   HaNoi  3.5
# 1   Binh   21     HCM  3.8
# 2  Cuong   22  DaNang  3.2
# 3   Dung   23   HaNoi  3.6
# (4, 4)
# Index(['Name', 'Age', 'City', 'GPA'], dtype='str')
# [['An' 20 'HaNoi' 3.5]
#  ['Binh' 21 'HCM' 3.8]
#  ['Cuong' 22 'DaNang' 3.2]
#  ['Dung' 23 'HaNoi' 3.6]]
# <bound method NDFrame.describe of     Name  Age    City  GPA
# 0     An   20   HaNoi  3.5
# 1   Binh   21     HCM  3.8
# 2  Cuong   22  DaNang  3.2
# 3   Dung   23   HaNoi  3.6>

# %%
df['Name']
# Out:
# 0       An
# 1     Binh
# 2    Cuong
# 3     Dung
# Name: Name, dtype: str

# %%
df[['Name','GPA']]
# Out:
#     Name  GPA
# 0     An  3.5
# 1   Binh  3.8
# 2  Cuong  3.2
# 3   Dung  3.6
